# %%
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fifa19 = pd.read_csv("fifa19.csv")
fifa19.head(3)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
#
# [3 rows x 89 columns]

# %%
fifa19.shape
# Out:
# (18207, 89)

# %%
fifa19.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
# drop column 'Unnamed: 0'
fifa19 = fifa19.drop('Unnamed: 0', 1)
fifa19.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
fifa19.head(3)
fifa19.Age.describe()
# Out:
# count    18207.000000
# mean        25.122206
# std          4.669943
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         28.000000
# max         45.000000
# Name: Age, dtype: float64

# %% [markdown]
# # AGE

# %%
# 5 oldest players
fifa19.sort_values(by=['Age'], ascending=False, inplace=True)
fifa19.head(5)
# Out:
#            ID           Name  Age  \
# 4741   140029       O. Pérez   45
# 18183   53748  K. Pilkington   44
# 17726   51963      T. Warner   44
# 10545  140183    S. Narazaki   42
# 7225   142998       C. Muñoz   41
#
#                                                 Photo        Nationality  \
# 4741   https://cdn.sofifa.org/players/4/19/140029.png             Mexico
# 18183   https://cdn.sofifa.org/players/4/19/53748.png            England
# 17726   https://cdn.sofifa.org/players/4/19/51963.png  Trinidad & Tobago
# 10545  https://cdn.sofifa.org/players/4/19/140183.png              Japan
# 7225   https://cdn.sofifa.org/players/4/19/142998.png          Argentina
#
#                                        Flag  Overall  Potential  \
# 4741    https://cdn.sofifa.org/flags/83.png       71         71
# 18183   https://cdn.sofifa.org/flags/14.png       48         48
# 17726   https://cdn.sofifa.org/flags/93.png       53         53
# 10545  https://cdn.sofifa.org/flags/163.png       65         65
# 7225    https://cdn.sofifa.org/flags/52.png       68         68
#
#                                Club  \
# 4741                        Pachuca
# 18183              Cambridge United
# 17726            Accrington Stanley
# 10545                Nagoya Grampus
# 7225   CD Universidad de Concepción
#
#                                              Club Logo  ... Composure Marking  \
# 4741   https://cdn.sofifa.org/teams/2/light/110147.png  ...      62.0    23.0
# 18183    https://cdn.sofifa.org/teams/2/light/1944.png  ...      56.0    15.0
# 17726  https://cdn.sofifa.org/teams/2/light/110313.png  ...      46.0    19.0
# 10545  https://cdn.sofifa.org/teams/2/light/112092.png  ...      45.0    27.0
# 7225   https://cdn.sofifa.org/teams/2/light/112534.png  ...      62.0    18.0
#
#        StandingTackle SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 4741             12.0          11.0      70.0        64.0       65.0
# 18183            15.0          13.0      45.0        48.0       44.0
# 17726            15.0          14.0      48.0        56.0       56.0
# 10545            24.0          22.0      64.0        63.0       62.0
# 7225             14.0          19.0      67.0        65.0       68.0
#
#       GKPositioning GKReflexes Release Clause
# 4741           73.0       74.0          €272K
# 18183          49.0       46.0            NaN
# 17726          60.0       44.0            NaN
# 10545          67.0       63.0           €50K
# 7225           71.0       68.0           €84K
#
# [5 rows x 88 columns]

# %%
# 5 youngest players
fifa19.sort_values(by=['Age'], ascending=True, inplace=True)
fifa19.head(5)
# Out:
#            ID        Name  Age  \
# 18206  246269   G. Nugent   16
# 17175  243353    B. Mumba   16
# 17115  245341  C. Bassett   16
# 17091  243269    A. Doğan   16
# 16927  243646   B. Nygren   16
#
#                                                 Photo    Nationality  \
# 18206  https://cdn.sofifa.org/players/4/19/246269.png        England
# 17175  https://cdn.sofifa.org/players/4/19/243353.png        England
# 17115  https://cdn.sofifa.org/players/4/19/245341.png  United States
# 17091  https://cdn.sofifa.org/players/4/19/243269.png         Turkey
# 16927  https://cdn.sofifa.org/players/4/19/243646.png         Sweden
#
#                                       Flag  Overall  Potential  \
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
# 17175  https://cdn.sofifa.org/flags/14.png       55         80
# 17115  https://cdn.sofifa.org/flags/95.png       55         77
# 17091  https://cdn.sofifa.org/flags/48.png       55         71
# 16927  https://cdn.sofifa.org/flags/46.png       56         73
#
#                   Club                                        Club Logo  ...  \
# 18206  Tranmere Rovers   https://cdn.sofifa.org/teams/2/light/15048.png  ...
# 17175       Sunderland     https://cdn.sofifa.org/teams/2/light/106.png  ...
# 17115  Colorado Rapids     https://cdn.sofifa.org/teams/2/light/694.png  ...
# 17091      Kayserispor  https://cdn.sofifa.org/teams/2/light/101020.png  ...
# 16927     IFK Göteborg     https://cdn.sofifa.org/teams/2/light/319.png  ...
#
#       Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 18206      43.0    40.0            43.0          50.0      10.0        15.0
# 17175      54.0    55.0            56.0          54.0      14.0         9.0
# 17115      48.0    52.0            54.0          52.0      14.0        15.0
# 17091      41.0    52.0            67.0          58.0      14.0        14.0
# 16927      43.0    18.0            16.0          18.0       6.0        10.0
#
#        GKKicking GKPositioning GKReflexes Release Clause
# 18206        9.0          12.0        9.0          €165K
# 17175        8.0          11.0       14.0          €523K
# 17115       11.0          12.0        5.0          €441K
# 17091       10.0           5.0        8.0          €420K
# 16927        6.0          12.0        8.0          €338K
#
# [5 rows x 88 columns]

# %%
# mean of ages
fifa19.Age.mean()
# Out:
# 25.122205745043114

# %%
# histogram
fifa19.Age.plot(kind='hist')

# %%
# describe
fifa19.Age.describe()
# Out:
# count    18207.000000
# mean        25.122206
# std          4.669943
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         28.000000
# max         45.000000
# Name: Age, dtype: float64

# %% [markdown]
# # PLAYER BY COUNTRY

# %%
top10 = fifa19.groupby('Nationality').count().sort_values(by=['Name'], ascending=False).head(10)
top10
# Out:
#                ID  Name   Age  Photo  Flag  Overall  Potential  Club  \
# Nationality
# England      1662  1662  1662   1662  1662     1662       1662  1662
# Germany      1198  1198  1198   1198  1198     1198       1198  1198
# Spain        1072  1072  1072   1072  1072     1072       1072  1072
# Argentina     937   937   937    937   937      937        937   936
# France        914   914   914    914   914      914        914   914
# Brazil        827   827   827    827   827      827        827   827
# Italy         702   702   702    702   702      702        702   702
# Colombia      618   618   618    618   618      618        618   618
# Japan         478   478   478    478   478      478        478   478
# Netherlands   453   453   453    453   453      453        453   453
#
#              Club Logo  Value  ...  Composure  Marking  StandingTackle  \
# Nationality                    ...
# England           1662   1662  ...       1657     1657            1657
# Germany           1198   1198  ...       1195     1195            1195
# Spain             1072   1072  ...       1071     1071            1071
# Argentina          937    937  ...        936      936             936
# France             914    914  ...        911      911             911
# Brazil             827    827  ...        825      825             825
# Italy              702    702  ...        699      699             699
# Colombia           618    618  ...        616      616             616
# Japan              478    478  ...        478      478             478
# Netherlands        453    453  ...        452      452             452
#
#              SlidingTackle  GKDiving  GKHandling  GKKicking  GKPositioning  \
# Nationality
# England               1657      1657        1657       1657           1657
# Germany               1195      1195        1195       1195           1195
# Spain                 1071      1071        1071       1071           1071
# Argentina              936       936         936        936            936
# France                 911       911         911        911            911
# Brazil                 825       825         825        825            825
# Italy                  699       699         699        699            699
# Colombia               616       616         616        616            616
# Japan                  478       478         478        478            478
# Netherlands            452       452         452        452            452
#
#              GKReflexes  Release Clause
# Nationality
# England            1657            1475
# Germany            1195            1151
# Spain              1071             974
# Argentina           936             833
# France              911             853
# Brazil              825             788
# Italy               699             579
# Colombia            616             570
# Japan               478             455
# Netherlands         452             426
#
# [10 rows x 87 columns]

# %%
# show up top 10 on bar chart
top10['ID'].plot(kind='barh')

# %% [markdown]
# # PLAYER BY CLUB

# %%
fifa19.groupby('Club').count().sort_values(by='ID', ascending=False).head()
# Out:
#                    ID  Name  Age  Photo  Nationality  Flag  Overall  \
# Club
# Borussia Dortmund  33    33   33     33           33    33       33
# Tottenham Hotspur  33    33   33     33           33    33       33
# Chelsea            33    33   33     33           33    33       33
# Valencia CF        33    33   33     33           33    33       33
# Everton            33    33   33     33           33    33       33
#
#                    Potential  Club Logo  Value  ...  Composure  Marking  \
# Club                                            ...
# Borussia Dortmund         33         33     33  ...         33       33
# Tottenham Hotspur         33         33     33  ...         33       33
# Chelsea                   33         33     33  ...         33       33
# Valencia CF               33         33     33  ...         33       33
# Everton                   33         33     33  ...         32       32
#
#                    StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# Club
# Borussia Dortmund              33             33        33          33
# Tottenham Hotspur              33             33        33          33
# Chelsea                        33             33        33          33
# Valencia CF                    33             33        33          33
# Everton                        32             32        32          32
#
#                    GKKicking  GKPositioning  GKReflexes  Release Clause
# Club
# Borussia Dortmund         33             33          33              32
# Tottenham Hotspur         33             33          33              33
# Chelsea                   33             33          33              32
# Valencia CF               33             33          33              30
# Everton                   32             32          32              30
#
# [5 rows x 87 columns]

# %%
fifa19.groupby('Club').mean().sort_values(by='Overall', ascending=False).head()
# Out:
#                         ID        Age    Overall  Potential      Special  \
# Club
# Juventus     187675.680000  27.160000  82.280000  85.520000  1904.400000
# Napoli       203013.520000  25.920000  80.000000  83.440000  1856.960000
# Inter        192522.666667  27.458333  79.750000  81.750000  1836.958333
# Real Madrid  213881.000000  24.030303  78.242424  84.636364  1818.939394
# Milan        199943.666667  25.000000  78.074074  82.555556  1823.296296
#
#              International Reputation  Weak Foot  Skill Moves  Jersey Number  \
# Club
# Juventus                     2.520000   3.200000     2.880000      13.720000
# Napoli                       2.160000   3.360000     2.880000      17.200000
# Inter                        2.166667   3.291667     2.875000      27.583333
# Real Madrid                  2.090909   3.212121     2.848485      17.666667
# Milan                        2.111111   3.000000     2.925926      23.888889
#
#               Crossing  ...  Penalties  Composure    Marking  StandingTackle  \
# Club                    ...
# Juventus     60.680000  ...  56.600000  77.800000  64.000000       62.120000
# Napoli       61.240000  ...  52.400000  73.000000  59.160000       59.880000
# Inter        57.958333  ...  53.500000  75.583333  59.208333       57.625000
# Real Madrid  58.606061  ...  52.878788  70.303030  57.030303       56.060606
# Milan        59.777778  ...  53.370370  72.777778  61.703704       56.296296
#
#              SlidingTackle   GKDiving  GKHandling  GKKicking  GKPositioning  \
# Club
# Juventus         59.880000  16.760000   16.080000  15.440000      17.520000
# Napoli           57.840000  18.720000   16.920000  16.760000      18.800000
# Inter            55.583333  20.000000   19.166667  18.333333      19.375000
# Real Madrid      53.121212  19.000000   19.000000  17.666667      17.545455
# Milan            53.481481  19.777778   20.000000  18.111111      18.740741
#
#              GKReflexes
# Club
# Juventus      18.000000
# Napoli        18.840000
# Inter         21.125000
# Real Madrid   18.636364
# Milan         19.037037
#
# [5 rows x 43 columns]

# %% [markdown]
# # TOP PLYAER BY SKILL

# %%
fifa19.sort_values(by=['Overall'], ascending=False, inplace=True)
fifa19.head(5)
# Out:
#        ID               Name  Age  \
# 1   20801  Cristiano Ronaldo   33
# 0  158023           L. Messi   31
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 7  176580          L. Suárez   31
#
#                                             Photo Nationality  \
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
#
#                                   Flag  Overall  Potential  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 7  https://cdn.sofifa.org/flags/60.png       91         91
#
#                   Club                                     Club Logo  ...  \
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png  ...
# 7         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
#
#   Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 1      95.0    28.0            31.0          23.0       7.0        11.0
# 0      96.0    33.0            28.0          26.0       6.0        11.0
# 2      94.0    27.0            24.0          33.0       9.0         9.0
# 3      68.0    15.0            21.0          13.0      90.0        85.0
# 7      85.0    62.0            45.0          38.0      27.0        25.0
#
#    GKKicking GKPositioning GKReflexes Release Clause
# 1       15.0          14.0       11.0        €127.1M
# 0       15.0          14.0        8.0        €226.5M
# 2       15.0          15.0       11.0        €228.1M
# 3       87.0          88.0       94.0        €138.6M
# 7       31.0          33.0       37.0          €164M
#
# [5 rows x 88 columns]

# %% [markdown]
# # TOP PLYAER BY VALUE

# %%
fifa19.Value.describe()
# Out:
# count     18207
# unique      217
# top       €1.1M
# freq        431
# Name: Value, dtype: object

# %%
# unique value
fifa19.Value.unique()
# Out:
# array(['€77M', '€110.5M', '€118.5M', '€72M', '€80M', '€93M', '€67M',
#        '€102M', '€51M', '€68M', '€60M', '€76.5M', '€44M', '€78M',
#        '€53.5M', '€63M', '€83.5M', '€58M', '€38M', '€51.5M', '€27M',
#        '€64.5M', '€89M', '€59.5M', '€59M', '€69.5M', '€73.5M', '€57M',
#        '€43M', '€81M', '€36M', '€62M', '€4M', '€24M', '€30M', '€46M',
#        '€64M', '€62.5M', '€30.5M', '€46.5M', '€34M', '€45M', '€52M',
#        '€43.5M', '€56.5M', '€45.5M', '€41.5M', '€21.5M', '€35M', '€44.5M',
#        '€39M', '€61M', '€53M', '€50M', '€36.5M', '€18M', '€55M', '€37M',
#        '€50.5M', '€40.5M', '€37.5M', '€15.5M', '€28.5M', '€54M', '€22M',
#        '€26M', '€14M', '€35.5M', '€9M', '€33M', '€32M', '€38.5M', '€29M',
#        '€16.5M', '€29.5M', '€42.5M', '€31.5M', '€27.5M', '€42M', '€24.5M',
#        '€19M', '€31M', '€25M', '€4.2M', '€23M', '€17.5M', '€21M',
#        '€34.5M', '€40M', '€20M', '€11.5M', '€25.5M', '€13M', '€8M',
#        '€28M', '€26.5M', '€6M', '€41M', '€32.5M', '€22.5M', '€18.5M',
#        '€19.5M', '€23.5M', '€17M', '€4.8M', '€15M', '€13.5M', '€12.5M',
#        '€20.5M', '€3M', '€1.5M', '€6.5M', '€11M', '€5.5M', '€16M',
#        '€14.5M', '€7M', '€10M', '€0', '€4.5M', '€12M', '€8.5M', '€10.5M',
#        '€9.5M', '€2M', '€1.7M', '€1M', '€7.5M', '€3.6M', '€3.8M', '€5M',
#        '€2.9M', '€2.4M', '€2.1M', '€4.1M', '€3.2M', '€600K', '€4.7M',
#        '€3.4M', '€2.7M', '€2.5M', '€2.2M', '€4.4M', '€3.1M', '€4.3M',
#        '€3.9M', '€2.3M', '€525K', '€4.9M', '€1.8M', '€3.7M', '€3.5M',
#        '€1.6M', '€900K', '€775K', '€450K', '€1.9M', '€4.6M', '€2.8M',
#        '€375K', '€650K', '€1.3M', '€1.2M', '€2.6M', '€750K', '€3.3M',
#        '€950K', '€1.1M', '€270K', '€550K', '€425K', '€725K', '€675K',
#        '€1.4M', '€975K', '€210K', '€875K', '€160K', '€325K', '€850K',
#        '€800K', '€500K', '€825K', '€240K', '€625K', '€925K', '€575K',
#        '€120K', '€200K', '€140K', '€700K', '€70K', '€250K', '€230K',
#        '€475K', '€350K', '€400K', '€300K', '€100K', '€60K', '€260K',
#        '€280K', '€180K', '€220K', '€290K', '€90K', '€50K', '€40K',
#        '€150K', '€130K', '€170K', '€190K', '€30K', '€110K', '€80K',
#        '€20K', '€10K'], dtype=object)

# %%
# convert value data
def convert_value(value):
    if value.endswith('K'):
        return float(value.replace('€','').replace('K','')) * 1000
    if value.endswith('M'):
        return float(value.replace('€','').replace('M','')) * 1000000
    
fifa19.Value = fifa19.Value.apply(convert_value)
fifa19.head()
# Out:
#        ID               Name  Age  \
# 1   20801  Cristiano Ronaldo   33
# 0  158023           L. Messi   31
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 7  176580          L. Suárez   31
#
#                                             Photo Nationality  \
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
#
#                                   Flag  Overall  Potential  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 7  https://cdn.sofifa.org/flags/60.png       91         91
#
#                   Club                                     Club Logo  ...  \
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png  ...
# 7         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
#
#    Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 1       95.0    28.0            31.0          23.0       7.0        11.0
# 0       96.0    33.0            28.0          26.0       6.0        11.0
# 2       94.0    27.0            24.0          33.0       9.0         9.0
# 3       68.0    15.0            21.0          13.0      90.0        85.0
# 7       85.0    62.0            45.0          38.0      27.0        25.0
#
#    GKKicking GKPositioning GKReflexes Release Clause
# 1       15.0          14.0       11.0        €127.1M
# 0       15.0          14.0        8.0        €226.5M
# 2       15.0          15.0       11.0        €228.1M
# 3       87.0          88.0       94.0        €138.6M
# 7       31.0          33.0       37.0          €164M
#
# [5 rows x 88 columns]

# %% [markdown]
# # LEFT AND RIGHT FOOT

# %%
fifa19.groupby('Preferred Foot').count()
# Out:
#                    ID   Name    Age  Photo  Nationality   Flag  Overall  \
# Preferred Foot
# Left             4211   4211   4211   4211         4211   4211     4211
# Right           13948  13948  13948  13948        13948  13948    13948
#
#                 Potential   Club  Club Logo  ...  Composure  Marking  \
# Preferred Foot                               ...
# Left                 4211   4162       4211  ...       4211     4211
# Right               13948  13756      13948  ...      13948    13948
#
#                 StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# Preferred Foot
# Left                      4211           4211      4211        4211
# Right                    13948          13948     13948       13948
#
#                 GKKicking  GKPositioning  GKReflexes  Release Clause
# Preferred Foot
# Left                 4211           4211        4211            3820
# Right               13948          13948       13948           12823
#
# [2 rows x 87 columns]
